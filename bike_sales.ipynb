# %%
import pandas as pd
import numpy as num 
import matplotlib as mat
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("C:/Users/PC/Desktop/Sales.csv")
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.tail()
# Out:
#               Date  Day  Month  Year  Customer_Age       Age_Group  \
# 113031  2016-04-12   12  April  2016            41  Adults (35-64)
# 113032  2014-04-02    2  April  2014            18     Youth (<25)
# 113033  2016-04-02    2  April  2016            18     Youth (<25)
# 113034  2014-03-04    4  March  2014            37  Adults (35-64)
# 113035  2016-03-04    4  March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# 113031               M  United Kingdom        England         Clothing
# 113032               M       Australia     Queensland         Clothing
# 113033               M       Australia     Queensland         Clothing
# 113034               F          France  Seine (Paris)         Clothing
# 113035               F          France  Seine (Paris)         Clothing
#
#        Sub_Category          Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (113036, 18)
# 113036
# 18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
from tabulate import tabulate

def sep(df):
    cateogrical=[]
    continuous=[]
    for col in df.columns:
        if df[col].nunique()<100:
            cateogrical.append(col)
        else:
            continuous.append(col)
    return cateogrical,continuous
categorical,continous=sep(df)

table=[categorical,continous]
print(tabulate({"Categorical":categorical,
                "Continous":continous
                },headers=["Categorical","Continuous"]))
# Out:
# Categorical       Continuous
# ----------------  ------------
# Day               Date
# Month             Product
# Year              Profit
# Customer_Age      Cost
# Age_Group         Revenue
# Customer_Gender
# Country
# State
# Product_Category
# Sub_Category
# Order_Quantity
# Unit_Cost
# Unit_Price

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %%
def info_of_cat(col):
    print("Unique values in",col,"are: ",df[col].unique())
    print("Mode of", col,"is: ",df[col].mode()[0])
    print("No of missing values in", col,"is",df[col].isnull().sum())
    if df[col].isnull().sum()>0:
        print("\nThere are null values in the",col,"column")

# %%
def info_of_num(col):
    print("Mean of the ",col," is: ",df[col].mean())
    print("Median of the ",col," is: ",df[col].median())
    print("Mode of the ",col," is: ",df[col].mode()[0])
    print("Standard deviation of the ",col," is: ",df[col].std())
    print("Missing values of ",col," are: ",df[col].isnull().sum())

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
info_of_cat("Customer_Age")
# Out:
# Unique values in Customer_Age are:  [19 49 47 35 32 34 29 51 48 43 61 57 38 52 24 23 26 54 46 41 33 42 45 53
#  21 22 67 31 37 87 25 40 44 55 50 59 17 27 28 36 56 58 30 18 62 39 64 63
#  20 60 84 68 65 73 69 66 75 76 78 71 72 82 86 77 74 85 81 80 70 79]
# Mode of Customer_Age is:  31
# No of missing values in Customer_Age is 0

# %%
x=df["Customer_Age"].value_counts()
y=x.index
xx=x.values
plt.barh(y,xx)

# plt.show()
xx
# Out:
# array([4382, 4300, 4214, 4092, 3988, 3968, 3958, 3836, 3604, 3540, 3482,
#        3352, 3328, 3178, 3050, 3044, 3040, 3010, 2922, 2826, 2672, 2636,
#        2608, 2236, 2230, 2148, 2020, 2010, 1918, 1800, 1776, 1774, 1760,
#        1634, 1582, 1380, 1306, 1206, 1170,  974,  912,  690,  654,  588,
#         506,  396,  322,  284,  196,   68,   64,   56,   50,   42,   36,
#          32,   24,   22,   22,   18,   16,   16,   16,   12,   10,    8,
#           6,    6,    6,    4], dtype=int64)

# %% [markdown]
# Interpretation: 4382 people have age 31 which is the highest among others.

# %%
# fig,ax=plt.subplots(1,2,figsize=(15,20))
matplotlib.rcParams['figure.figsize'] = (28, 16)
sns.countplot(x=df["Customer_Age"])
plt.xlabel('Age')
plt.ylabel('Sales')
# l=df["Customer_Age"].value_counts()
# plt.pie(l,labels=y,autopct="%0.2f%%")

plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Age_Group

# %%
info_of_cat("Age_Group")
# Out:
# Unique values in Age_Group are:  ['Youth (<25)' 'Adults (35-64)' 'Young Adults (25-34)' 'Seniors (64+)']
# Mode of Age_Group is:  Adults (35-64)
# No of missing values in Age_Group is 0

# %%
df["Age_Group"].value_counts()
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
figure=plt.figure(figsize=(15,7))
sns.countplot(y=df["Age_Group"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Age_Group'>

# %% [markdown]
# 55824 People belong to the category of Adults(35-64) which means that adults whose age grp is between 35 and 64 enjoys biking as a hobby or they have a single means of transport as bike which they use to cummute to their work.

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Customer_Gender

# %%
info_of_cat("Customer_Gender")
# Out:
# Unique values in Customer_Gender are:  ['M' 'F']
# Mode of Customer_Gender is:  M
# No of missing values in Customer_Gender is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
# for bar graph
sns.countplot(x=df["Customer_Gender"],ax=ax[0])

# for pie chart
y=df["Customer_Gender"].value_counts()
labels=y.index
plt.pie(y,labels=labels,autopct="%0.2f%%")

plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Country

# %%
info_of_cat("Country")
# Out:
# Unique values in Country are:  ['Canada' 'Australia' 'United States' 'Germany' 'France' 'United Kingdom']
# Mode of Country is:  United States
# No of missing values in Country is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
plt.xlabel("")
sns.countplot(y=df["Country"],ax=ax[0])
a=df["Country"].value_counts()
b=a.index
c=a.values
plt.pie(c,labels=b,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# Most of the customers have been from the US

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## State

# %%
info_of_cat("State")
# Out:
# Unique values in State are:  ['British Columbia' 'New South Wales' 'Victoria' 'Oregon' 'California'
#  'Saarland' 'Seine Saint Denis' 'Moselle' 'Queensland' 'England' 'Nord'
#  'Washington' 'Hessen' 'Nordrhein-Westfalen' 'Hamburg' 'Loir et Cher'
#  'Kentucky' 'Seine (Paris)' 'South Australia' 'Loiret' 'Alberta' 'Bayern'
#  'Hauts de Seine' 'Yveline' 'Essonne' "Val d'Oise" 'Tasmania'
#  'Seine et Marne' 'Val de Marne' 'Pas de Calais' 'Charente-Maritime'
#  'Garonne (Haute)' 'Brandenburg' 'Texas' 'New York' 'Florida' 'Somme'
#  'Illinois' 'South Carolina' 'North Carolina' 'Georgia' 'Virginia' 'Ohio'
#  'Ontario' 'Wyoming' 'Missouri' 'Montana' 'Utah' 'Minnesota' 'Mississippi'
#  'Massachusetts' 'Arizona' 'Alabama']
# Mode of State is:  California
# No of missing values in State is 0

# %%
df["State"].value_counts()
# Out:
# California             22450
# British Columbia       14116
# England                13620
# Washington             11264
# New South Wales        10412
# Victoria                6016
# Oregon                  5286
# Queensland              5220
# Saarland                2770
# Nordrhein-Westfalen     2484
# Hessen                  2384
# Seine (Paris)           2328
# Hamburg                 1836
# Seine Saint Denis       1684
# Nord                    1670
# South Australia         1564
# Bayern                  1426
# Hauts de Seine          1084
# Essonne                  994
# Yveline                  954
# Tasmania                 724
# Seine et Marne           394
# Moselle                  386
# Loiret                   382
# Val d'Oise               264
# Garonne (Haute)          208
# Brandenburg              198
# Val de Marne             158
# Charente-Maritime        148
# Somme                    134
# Loir et Cher             120
# Pas de Calais             90
# ...

# %%
figure=plt.figure(figsize=(15,10))
sns.countplot(y=df["State"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='State'>

# %% [markdown]
# California has the highest no of customers

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Product_Category

# %%
info_of_cat("Product_Category")
# Out:
# Unique values in Product_Category are:  ['Accessories' 'Clothing' 'Bikes']
# Mode of Product_Category is:  Accessories
# No of missing values in Product_Category is 0

# %%
a=df["Product_Category"].value_counts()
a
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=df["Product_Category"],ax=ax[0])

a=df["Product_Category"].value_counts()
b=a.index
c=a.values
plt.pie(c,labels=b,autopct="%0.02f%%")
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Sub_Category

# %%
info_of_cat("Sub_Category")
# Out:
# Unique values in Sub_Category are:  ['Bike Racks' 'Bike Stands' 'Bottles and Cages' 'Caps' 'Cleaners'
#  'Fenders' 'Gloves' 'Helmets' 'Hydration Packs' 'Jerseys' 'Mountain Bikes'
#  'Road Bikes' 'Shorts' 'Socks' 'Tires and Tubes' 'Touring Bikes' 'Vests']
# Mode of Sub_Category is:  Tires and Tubes
# No of missing values in Sub_Category is 0

# %%
figure=plt.figure(figsize=(15,10))
sns.countplot(y=df["Sub_Category"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Sub_Category'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Unit_Cost

# %%
info_of_cat("Unit_Cost")
# Out:
# Unique values in Unit_Cost are:  [  45   59    4    2    3    7    8    9   13   21   42   38 1912 1898
#  1266 1252  420  308  295 2171  344 1083 1555  713 1519  487   26    1
#    11   12 1482  461  755   24]
# Mode of Unit_Cost is:  2
# No of missing values in Unit_Cost is 0

# %%
figure=plt.figure(figsize=(15,10))
sns.countplot(y=df["Unit_Cost"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Unit_Cost'>

# %% [markdown]
# ## Numerical Analysis

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
info_of_num("Order_Quantity")
# Out:
# Mean of the  Order_Quantity  is:  11.901659648253654
# Median of the  Order_Quantity  is:  10.0
# Mode of the  Order_Quantity  is:  1
# Standard deviation of the  Order_Quantity  is:  9.56185675955091
# Missing values of  Order_Quantity  are:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["Order_Quantity"],ax=ax[0])
sns.boxplot(x=df["Order_Quantity"],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Order_Quantity'>

# %% [markdown]
# ## Profit

# %%
info_of_num("Profit")
# Out:
# Mean of the  Profit  is:  285.0516649562971
# Median of the  Profit  is:  101.0
# Mode of the  Profit  is:  3
# Standard deviation of the  Profit  is:  453.8874430557028
# Missing values of  Profit  are:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(df["Profit"],ax=ax[0])
sns.boxplot(df["Profit"],ax=ax[1])
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %%
df["Profit"].describe()
# Out:
# count    113036.000000
# mean        285.051665
# std         453.887443
# min         -30.000000
# 25%          29.000000
# 50%         101.000000
# 75%         358.000000
# max       15096.000000
# Name: Profit, dtype: float64

# %%
percentile_1=29
percentile_3=358
IQR=percentile_3-percentile_1

# %%
upper_limit=percentile_3+1.5*IQR
lower_limit=percentile_1-1.5*IQR

# %%
x=df[(df["Profit"]>upper_limit)|(df["Profit"]<lower_limit)].index
x
# Out:
# Int64Index([     2,      3,      8,      9,     30,     31,     32,     33,
#                 36,     37,
#             ...
#             112979, 112983, 112994, 112995, 113010, 113011, 113020, 113021,
#             113022, 113023],
#            dtype='int64', length=10021)

# %%
df['Profit'].plot(kind="density" , figsize=(12,6), fontsize=12)
plt.title("Unit Cost",fontsize=15)
plt.xlabel("Unit Cost",fontsize=12)
plt.ylabel("Sales",fontsize=12)
# Out:
# Text(0, 0.5, 'Sales')

# %%
ax=df['Profit'].plot(kind="density" , figsize=(12,6), fontsize=12)
mean= ax.axvline(df['Profit'].mean(), color='red' )
median = ax.axvline(df['Profit'].median(), color='g')
plt.legend({'Median':median,'Mean':mean})

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
info_of_num("Cost")
# Out:
# Mean of the  Cost  is:  469.3186949290492
# Median of the  Cost  is:  108.0
# Mode of the  Cost  is:  1252
# Standard deviation of the  Cost  is:  884.8661177053738
# Missing values of  Cost  are:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["Cost"],ax=ax[0])
sns.boxplot(x=df["Cost"],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Cost'>

# %%
df["Cost"].describe()
# Out:
# count    113036.000000
# mean        469.318695
# std         884.866118
# min           1.000000
# 25%          28.000000
# 50%         108.000000
# 75%         432.000000
# max       42978.000000
# Name: Cost, dtype: float64

# %%
percentile_1=df["Cost"].quantile(0.25)
percentile_3=df["Cost"].quantile(0.75)
IQR=percentile_3-percentile_1

# %%
upper_limit=percentile_3+1.5*IQR
lower_limit=percentile_1-1.5*IQR

# %%
x=df[(df["Cost"]>upper_limit) | (df["Cost"]<lower_limit)].index
mean=int(df["Cost"].mean())
for index in x:
    df.loc[index,"Cost"]=mean

# %%
df["Cost"].describe()
# Out:
# count    113036.000000
# mean        212.975229
# std         224.115188
# min           1.000000
# 25%          28.000000
# 50%         108.000000
# 75%         432.000000
# max        1035.000000
# Name: Cost, dtype: float64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["Cost"],ax=ax[0])
sns.boxplot(x=df["Cost"],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Cost'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
info_of_num("Revenue")
# Out:
# Mean of the  Revenue  is:  754.3703598853463
# Median of the  Revenue  is:  223.0
# Mode of the  Revenue  is:  35
# Standard deviation of the  Revenue  is:  1309.0946735270197
# Missing values of  Revenue  are:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["Revenue"],ax=ax[0])
sns.boxplot(x=df["Revenue"],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Revenue'>

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ## revenue per year

# %%
df.groupby(["Year"])["Revenue"].sum().plot(kind='bar',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.groupby(["Year"])["Revenue"].sum().plot(kind='line',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## revenue per month

# %%
df.groupby(["Month"])["Revenue"].sum().plot(kind='bar',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ## revenue per country

# %%
df.groupby(["Country"])["Revenue"].sum().plot(kind='bar',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
g=df.loc[df['Country']=="Australia",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
g=df.loc[df['Country']=="Canada",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
g=df.loc[df['Country']=="United States",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
g=df.loc[df['Country']=="Germany",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
g=df.loc[df['Country']=="France",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
g=df.loc[df['Country']=="United Kingdom",["State","Revenue"]]
g.groupby("State")["Revenue"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
# def fun(df):
#    for country in df['Country'].unique():
#       l=list(country)
#       for i in l:
#          g=df.loc[df['Country']==i,["State","Revenue"]]
#          plot=g.groupby("State")["Revenue"].sum()
#    return plot

# %% [markdown]
# ## profit earned countrywise

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df.groupby("Country")["Profit"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## most profit earning state in USA

# %%
f=df.loc[df['Country']=="United States",["State","Profit"]]
f.groupby(["State"])["Profit"].sum().plot(kind='barh',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='State'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## total order quantity for bike related products

# %%
s=df.loc[df["Product_Category"]=="Bikes",["Product","Order_Quantity"]]
s.groupby(["Product"])["Order_Quantity"].sum().plot(kind="line",figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Product'>

# %% [markdown]
# ## Age grps of customer who bought mountain bikes

# %%
r=df.loc[(df["Product_Category"]=='Bikes') | (df["Sub_Category"]=="Mountain Bikes")]
r.Age_Group
sns.countplot(x=r.Age_Group)

#r.groupby(["Age_Group"]).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Age_Group', ylabel='count'>

# %%
b=df.loc[df["Product_Category"]=='Bikes']
b.groupby("Sub_Category")["Product"].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Sub_Category,Product'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df1=df.loc[df["Country"]=="Australia"]
df1.groupby(["Country"])["Sub_Category"].value_counts().plot(kind="bar",figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='Country,Sub_Category'>

# %%
df1.groupby(["Sub_Category"])["Cost"].sum().plot(kind='bar',figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='Sub_Category'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df2=df.loc[df["Product_Category"]=="Accessories"]
df2.groupby(["Product_Category"])["Sub_Category"].value_counts().plot(kind="bar",figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='Product_Category,Sub_Category'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df.groupby(["Customer_Gender"])["Cost"].sum().plot(kind='pie',autopct="%0.2f%%",figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Cost'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df.groupby(['Date'])['Revenue'].sum().plot(kind='line',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
r=df.groupby(['Country'])["Customer_Gender"].value_counts().to_frame(name='Gender_Count').reset_index()
r
# Out:
#            Country Customer_Gender  Gender_Count
# 0        Australia               M         12430
# 1        Australia               F         11506
# 2           Canada               M          7682
# 3           Canada               F          6496
# 4           France               F          5504
# 5           France               M          5494
# 6          Germany               F          5572
# 7          Germany               M          5526
# 8   United Kingdom               M          6908
# 9   United Kingdom               F          6712
# 10   United States               M         20272
# 11   United States               F         18934

# %%
fig=plt.figure(figsize=(10,7))
sns.barplot(x = 'Country', y = 'Gender_Count',hue='Customer_Gender', data = r)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Gender_Count'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
#fig=plt.figure(figsize=(10,10))
sns.barplot(x = 'Unit_Price', y = 'Unit_Cost',hue='Country', data = df)
# Out:
# <AxesSubplot:xlabel='Unit_Price', ylabel='Unit_Cost'>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
e=df.groupby("Age_Group")["Product_Category"].value_counts().to_frame(name='Count').reset_index()
e
# Out:
#                Age_Group Product_Category  Count
# 0         Adults (35-64)      Accessories  34750
# 1         Adults (35-64)            Bikes  12698
# 2         Adults (35-64)         Clothing   8376
# 3          Seniors (64+)      Accessories    572
# 4          Seniors (64+)         Clothing    102
# 5          Seniors (64+)            Bikes     56
# 6   Young Adults (25-34)      Accessories  22992
# 7   Young Adults (25-34)            Bikes   9834
# 8   Young Adults (25-34)         Clothing   5828
# 9            Youth (<25)      Accessories  11806
# 10           Youth (<25)            Bikes   3394
# 11           Youth (<25)         Clothing   2628

# %%
sns.barplot(x='Age_Group',y='Count',hue='Product_Category',data=e)
# Out:
# <AxesSubplot:xlabel='Age_Group', ylabel='Count'>

# %%
b.groupby("Sub_Category")["Unit_Price",'Unit_Cost'].sum().plot(kind='bar')
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_12868/1741270484.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   b.groupby("Sub_Category")["Unit_Price",'Unit_Cost'].sum().plot(kind='bar')
# <AxesSubplot:xlabel='Sub_Category'>

# %%
b[["Sub_Category","Unit_Price"]].value_counts().to_frame(name='')
# Out:
# Sub_Category    Unit_Price
# Road Bikes      3578          3290
# Mountain Bikes  2295          3126
#                 2320          3018
# Road Bikes      2443          2510
#                 540           2478
#                 1120          2156
# Touring Bikes   2384          2034
# Road Bikes      1701          1634
#                 783           1362
# Mountain Bikes  769           1162
# Touring Bikes   742            962
#                 1215           702
# Mountain Bikes  540            530
#                 565            470
#                 3375           286
#                 3400           262
# dtype: int64
