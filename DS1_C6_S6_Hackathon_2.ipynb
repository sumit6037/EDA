# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
df = pd.read_csv("C:/Users/PC/Desktop/credit1.csv") # read_csv: inbuilt function of pandas to read files
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %%
df.tail()
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED  \
# 99995          157500.0    755190.0         675000.0  ...          -232
# 99996          225000.0    284400.0         225000.0  ...          -182
# 99997          135000.0   1262583.0        1102500.0  ...         -4805
# 99998          135000.0    225000.0         225000.0  ...          -340
# 99999          202500.0    337500.0         337500.0  ...         -3230
#
#       MOBILE WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  \
# ...

# %%
print(df.shape)
# Out:
# (100000, 24)

# %%
df["OCCUPATION_TYPE"]
# Out:
# 0           Laborers
# 1         Core staff
# 2           Laborers
# 3           Laborers
# 4         Core staff
#             ...
# 99995    Sales staff
# 99996       Managers
# 99997    Sales staff
# 99998    Sales staff
# 99999        Drivers
# Name: OCCUPATION_TYPE, Length: 100000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %% [markdown]
# ## Visualizing the missing values
# With the help of heatmap, we can see the amount of data that is missing from the attribute.With this, we can make decisions whether to drop these missing values or to replace them. Usually dropping the missing values is not advisable but sometimes it may be helpful too.

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Replacing the missing values
# 1. For "AMT_GOODS_PRICE" Column

# %%
df['AMT_GOODS_PRICE'].mean()
# Out:
# 538345.1489706662

# %%
df['AMT_GOODS_PRICE']=df['AMT_GOODS_PRICE'].fillna(538345)

# %%
#df['AMT_GOODS_PRICE'].isnull().sum()

# %% [markdown]
# 2. For "NAME_TYPE_SUITE" Column

# %%
df["NAME_TYPE_SUITE"]=df["NAME_TYPE_SUITE"].fillna("Unaccompanied")

# %%
#df["NAME_TYPE_SUITE"].isnull().sum()

# %% [markdown]
# 3. For "OCCUPATION_TYPE" Column

# %%
df["OCCUPATION_TYPE"]=df["OCCUPATION_TYPE"].fillna("Unemployed")

# %%
df["OCCUPATION_TYPE"].isnull().sum()
# Out:
# 0

# %% [markdown]
# 4. For "CNT_FAM_MEMBERS" Column

# %%
df["CNT_FAM_MEMBERS"].mean()
# Out:
# 2.1556715567155673

# %%
df["CNT_FAM_MEMBERS"]=df["CNT_FAM_MEMBERS"].fillna(2.0)

# %%
df["CNT_FAM_MEMBERS"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %%
def info_of_cat(col):
    print("Unique values in",col,"are: ",df[col].unique())
    print("Mode of", col,"is: ",df[col].mode()[0])
    print("No of missing values in", col,"is",df[col].isnull().sum())
    if df[col].isnull().sum()>0:
        print("\nThere are null values in the",col,"column")

# %% [markdown]
# # 1. Analysis of Target:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("TARGET")
# Out:
# Unique values in TARGET are:  [1 0]
# Mode of TARGET is:  0
# No of missing values in TARGET is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of Target")
Percentage=df["TARGET"].value_counts()
labels=list(df["TARGET"].value_counts().index)

sns.countplot(x= df["TARGET"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: From the above analysis te 91.91% of the target belongs to the "other" cateogary and 8.09% of the target belong to the"Target variable 1 ie  client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample.

# %% [markdown]
# # 1. Analysis of Name Contract type:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("NAME_CONTRACT_TYPE")
# Out:
# Unique values in NAME_CONTRACT_TYPE are:  ['Cash loans' 'Revolving loans']
# Mode of NAME_CONTRACT_TYPE is:  Cash loans
# No of missing values in NAME_CONTRACT_TYPE is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of NAME_CONTRACT_TYPE")
Percentage=df["NAME_CONTRACT_TYPE"].value_counts()
labels=list(df["NAME_CONTRACT_TYPE"].value_counts().index)

sns.countplot(x= df["NAME_CONTRACT_TYPE"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: From the above analysis 90.52% of the applicants have applied for cash loans and 9.48% have applied for revolving loans.

# %% [markdown]
# # 1. Analysis of GENDER:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("GENDER")
# Out:
# Unique values in GENDER are:  ['M' 'F' 'XNA']
# Mode of GENDER is:  F
# No of missing values in GENDER is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of GENDER")
Percentage=df["GENDER"].value_counts()
labels=list(df["GENDER"].value_counts().index)

sns.countplot(x= df["GENDER"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpertation: From the above analysis 65.86% of the females are the loan applicants and 34.14% are male applicants.

# %% [markdown]
# # 1. Analysis of Car:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("Car")
# Out:
# Unique values in Car are:  ['N' 'Y']
# Mode of Car is:  N
# No of missing values in Car is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of Car")
Percentage=df["Car"].value_counts()
labels=list(df["Car"].value_counts().index)

sns.countplot(x= df["Car"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: From the above analysis 66.02% of the applicants don't have a car and 33.98% of the applicants own a car.

# %% [markdown]
# # 1. Analysis of  House:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("House")
# Out:
# Unique values in House are:  ['Y' 'N']
# Mode of House is:  Y
# No of missing values in House is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of House")
Percentage=df["House"].value_counts()
labels=list(df["House"].value_counts().index)

sns.countplot(x= df["House"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: From the above analysis 69.33% of the applicnts own a house and 30.67% of the applicants donot own a house.

# %% [markdown]
# # 1. Analysis of  NAME_INCOME_TYPE:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("NAME_INCOME_TYPE")
# Out:
# Unique values in NAME_INCOME_TYPE are:  ['Working' 'State servant' 'Commercial associate' 'Pensioner' 'Unemployed'
#  'Student' 'Businessman' 'Maternity leave']
# Mode of NAME_INCOME_TYPE is:  Working
# No of missing values in NAME_INCOME_TYPE is 0

# %%
fig=plt.subplots(figsize=(15,7))
sns.countplot(y ='NAME_INCOME_TYPE', data = df)
plt.show()

# %% [markdown]
# ## Interpretation: From the above analysis 51.90% of applicants belong to the Working class and followed by 7% of applicants are state servant.

# %% [markdown]
# # 1. Analysis of  NAME_EDUCATION_TYPE:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("NAME_EDUCATION_TYPE")
# Out:
# Unique values in NAME_EDUCATION_TYPE are:  ['Secondary / secondary special' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# Mode of NAME_EDUCATION_TYPE is:  Secondary / secondary special
# No of missing values in NAME_EDUCATION_TYPE is 0

# %%
fig=plt.subplots(figsize=(15,7))
sns.countplot(y ='NAME_EDUCATION_TYPE', data = df)
plt.show()

# %% [markdown]
# ## Interpretation: From the analysis it is clear that the 71.07% of Applicants have a Secondary education type whereas 0.05% of applicats have lower secondary education.The Applicants have Academic degree are negligible.

# %% [markdown]
# # 1. Analysis of  NAME_FAMILY_STATUS:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("NAME_FAMILY_STATUS")
# Out:
# Unique values in NAME_FAMILY_STATUS are:  ['Single / not married' 'Married' 'Civil marriage' 'Widow' 'Separated'
#  'Unknown']
# Mode of NAME_FAMILY_STATUS is:  Married
# No of missing values in NAME_FAMILY_STATUS is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of NAME_FAMILY_STATUS")
Percentage=df["NAME_FAMILY_STATUS"].value_counts()
labels=list(df["NAME_FAMILY_STATUS"].value_counts().index)

sns.countplot(y= df["NAME_FAMILY_STATUS"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: From the analysis it is clear that 64.06% of the applicants married and 5.25% of the applicants are widow.

# %% [markdown]
# # 1. Analysis of  MOBILE:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("MOBILE")
# Out:
# Unique values in MOBILE are:  [1 0]
# Mode of MOBILE is:  1
# No of missing values in MOBILE is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of MOBILE")
Percentage=df["MOBILE"].value_counts()
labels=list(df["MOBILE"].value_counts().index)

sns.countplot(y= df["MOBILE"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: Almost all the clients provided their mobile no

# %% [markdown]
# # 1. Analysis of  FLAG_EMAIL:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("FLAG_EMAIL")
# Out:
# Unique values in FLAG_EMAIL are:  [0 1]
# Mode of FLAG_EMAIL is:  0
# No of missing values in FLAG_EMAIL is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of FLAG_EMAIL")
Percentage=df["FLAG_EMAIL"].value_counts()
labels=list(df["FLAG_EMAIL"].value_counts().index)

sns.countplot(y= df["FLAG_EMAIL"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: 94.38% of the applicants didn't provide their email id

# %% [markdown]
# # 1. Analysis of  CNT_FAM_MEMBERS:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("CNT_FAM_MEMBERS")
# Out:
# Unique values in CNT_FAM_MEMBERS are:  [ 1.  2.  3.  4.  5.  6.  9.  7.  8. 10. 13. 14.]
# Mode of CNT_FAM_MEMBERS is:  2.0
# No of missing values in CNT_FAM_MEMBERS is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of CNT_FAM_MEMBERS")
Percentage=df["CNT_FAM_MEMBERS"].value_counts()
labels=list(df["CNT_FAM_MEMBERS"].value_counts().index)

sns.countplot(y= df["CNT_FAM_MEMBERS"],ax=ax[0])
plt.pie(Percentage,explode = [0.1, 0.1, 0.2, 0.3,0.3,0.1, 0.1, 0.2, 0.3,0.05,0.2,0.3],labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: 51.72% of the clients have 2 members in their family.

# %% [markdown]
# # 1. Analysis of  APPLICATION_DAY:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("APPLICATION_DAY")
# Out:
# Unique values in APPLICATION_DAY are:  ['WEDNESDAY' 'MONDAY' 'THURSDAY' 'SUNDAY' 'SATURDAY' 'FRIDAY' 'TUESDAY']
# Mode of APPLICATION_DAY is:  TUESDAY
# No of missing values in APPLICATION_DAY is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of APPLICATION_DAY")
Percentage=df["APPLICATION_DAY"].value_counts()
labels=list(df["APPLICATION_DAY"].value_counts().index)

sns.countplot(y= df["APPLICATION_DAY"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: 17.41% of the applicants have applied for loan on Tuesday

# %% [markdown]
# # 1. Analysis of  TOTAL_DOC_SUBMITTED:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("TOTAL_DOC_SUBMITTED")
# Out:
# Unique values in TOTAL_DOC_SUBMITTED are:  [1 0 2 3 4]
# Mode of TOTAL_DOC_SUBMITTED is:  1
# No of missing values in TOTAL_DOC_SUBMITTED is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of TOTAL_DOC_SUBMITTED")
Percentage=df["TOTAL_DOC_SUBMITTED"].value_counts()
labels=list(df["TOTAL_DOC_SUBMITTED"].value_counts().index)

sns.countplot(y= df["TOTAL_DOC_SUBMITTED"],ax=ax[0])
plt.pie(Percentage,explode = [0.1, 0.1, 0.2, 0.3,0.7],labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: 87.86% of the clients have submitted only 1 document.

# %% [markdown]
# # 1. Analysis of  CNT_CHILDREN:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
df["CNT_CHILDREN"].value_counts()
# Out:
# 0     69966
# 1     20025
# 2      8587
# 3      1227
# 4       149
# 5        31
# 6         9
# 7         2
# 8         1
# 9         1
# 11        1
# 12        1
# Name: CNT_CHILDREN, dtype: int64

# %%
info_of_cat("CNT_CHILDREN")
# Out:
# Unique values in CNT_CHILDREN are:  [ 0  1  2  3  4  7  5  6  8  9 11 12]
# Mode of CNT_CHILDREN is:  0
# No of missing values in CNT_CHILDREN is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of CNT_CHILDREN")
Percentage=df["CNT_CHILDREN"].value_counts()
labels=list(df["CNT_CHILDREN"].value_counts().index)

sns.countplot(y= df["CNT_CHILDREN"],ax=ax[0])
plt.pie(Percentage,labels=labels,autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Interpretation: Very few people have childern higher than 4. However, there are some cases where the children count is greater than 7, which is abnormal. Hence, data clearing might be  required. It should be noted that if these kind of abnormalities arises then it is adviced to contact the client.

# %% [markdown]
# # Outliers Analysis and Treatment:
# The clients who have a children count greater than 4 are replaced with the mean of the population.

# %%
mode=int(df["CNT_CHILDREN"].mode())
x=df[df["CNT_CHILDREN"]> 4].index
for index in x:
    df.loc[index, "CNT_CHILDREN"] = mode
    
# x = df[df["Dependent_count"] > 5].index

# %%
info_of_cat("CNT_CHILDREN")
# Out:
# Unique values in CNT_CHILDREN are:  [0 1 2 3 4]
# Mode of CNT_CHILDREN is:  0
# No of missing values in CNT_CHILDREN is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("Count of CNT_CHILDREN")
Percentage=df["CNT_CHILDREN"].value_counts()
labels=list(df["CNT_CHILDREN"].value_counts().index)

sns.countplot(y= df["CNT_CHILDREN"],ax=ax[0])
plt.pie(Percentage,explode = [0.1, 0.1, 0.2, 0.3,0.3],labels=labels,autopct="%0.2f%%")

plt.show()

# data = df["Card_Category"].value_counts()                                   #value count is counting the number of values in the column
# print(data)
# pie, ax = plt.subplots(1, 2, figsize = [20,6])
# labels =data.keys()                                                         # Keys returning you the index names in the data
# ax[0].pie(x = data, explode = [0.2, 0.2, 0.45, 0.67], labels = labels)         # pctdistance is the distance between the percentage on pie chart from center.
#                                                                                 #  explode is to split the slices by the distance provided
# sns.countplot(x = df["Card_Category"], ax = ax[1])                                                                                               
# plt.title("Card_Category")                                                  # title is used to prints the title on the image. 
# plt.show()

# %% [markdown]
# ## Interpretation: 90.03% of the population have either 1 or 2 childern.

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %%
def info_of_num(col):
    print("The mean of the",col,"is: ",df[col].mean())
    print("The median of the",col,"is: ",df[col].median())
    print("The mode of the",col,"is: ",df[col].mode()[0])
    print("The standard deviation of the",col,"is: ",df[col].std())
    print("Number of missing values in the",col,"is: ",df[col].isnull().sum())

# %% [markdown]
# # 11. Analysis of  the AMT_INCOME_TOTAL
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_num("AMT_INCOME_TOTAL")
# Out:
# The mean of the AMT_INCOME_TOTAL is:  169426.07027325002
# The median of the AMT_INCOME_TOTAL is:  144000.0
# The mode of the AMT_INCOME_TOTAL is:  135000.0
# The standard deviation of the AMT_INCOME_TOTAL is:  383500.74427718896
# Number of missing values in the AMT_INCOME_TOTAL is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(20,7))
sns.histplot(x=df['AMT_INCOME_TOTAL'],ax=ax[0])
sns.boxplot(x=df['AMT_INCOME_TOTAL'],ax=ax[1])
plt.show()

# %% [markdown]
# # Outliers Analysis and Treatment:
# Since the data is skwed IQR based filtering can be used.

# %%
df["AMT_INCOME_TOTAL"].describe()
# Out:
# count    1.000000e+05
# mean     1.694261e+05
# std      3.835007e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.440000e+05
# 75%      2.025000e+05
# max      1.170000e+08
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
percentile_1=1.125000e+05
percentile_3=2.025000e+05
IQR=percentile_3-percentile_1

# %%
upper_limit=percentile_3+1.5*IQR
lower_limit=percentile_1-1.5*IQR

# %%
##Finding Outliers
df1=df[df["AMT_INCOME_TOTAL"]>upper_limit]
df2=df[df["AMT_INCOME_TOTAL"]<lower_limit]

# %%
mean=int(df["AMT_INCOME_TOTAL"].mean())
x=df1.index
for index in x:
    df.loc[index,"AMT_INCOME_TOTAL"]=mean

# %%
info_of_num("AMT_INCOME_TOTAL")
# Out:
# The mean of the AMT_INCOME_TOTAL is:  154868.53801625
# The median of the AMT_INCOME_TOTAL is:  144000.0
# The mode of the AMT_INCOME_TOTAL is:  135000.0
# The standard deviation of the AMT_INCOME_TOTAL is:  62708.56441667292
# Number of missing values in the AMT_INCOME_TOTAL is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(20,7))
sns.histplot(x=df['AMT_INCOME_TOTAL'],ax=ax[0])
sns.boxplot(x=df['AMT_INCOME_TOTAL'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation: Most likely, total income of the applicant follows a normal distribution. Most of the total income of are between 100000 to 200000 .

# %% [markdown]
# # 11. Analysis of  the AMT_CREDIT
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_num("AMT_CREDIT")
# Out:
# The mean of the AMT_CREDIT is:  599003.4465
# The median of the AMT_CREDIT is:  513040.5
# The mode of the AMT_CREDIT is:  450000.0
# The standard deviation of the AMT_CREDIT is:  402051.9591213264
# Number of missing values in the AMT_CREDIT is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["AMT_CREDIT"],ax=ax[0])
sns.boxplot(x=df["AMT_CREDIT"],ax=ax[1])
plt.show()

# %% [markdown]
# # Outliers Analysis and Treatment:
# Since the data is skwed IQR based filtering can be used.

# %%
df["AMT_CREDIT"].describe()
# Out:
# count    1.000000e+05
# mean     5.990034e+05
# std      4.020520e+05
# min      4.500000e+04
# 25%      2.700000e+05
# 50%      5.130405e+05
# 75%      8.086500e+05
# max      4.050000e+06
# Name: AMT_CREDIT, dtype: float64

# %%
percentile_1=2.700000e+05
percentile_3=8.086500e+05
IQR=percentile_3-percentile_1

# %%
upper_limit=percentile_3+1.5*IQR
lower_limit=percentile_1-1.5*IQR

# %%
##Finding Outliers
df1=df[df["AMT_CREDIT"]>upper_limit]
df2=df[df["AMT_CREDIT"]<lower_limit]

# %%
mean=df["AMT_CREDIT"].mean()
x=df1.index
for index in x:
    df.loc[index,"AMT_CREDIT"]=mean

# %%
info_of_num("AMT_CREDIT")
# Out:
# The mean of the AMT_CREDIT is:  570615.509247093
# The median of the AMT_CREDIT is:  513040.5
# The mode of the AMT_CREDIT is:  450000.0
# The standard deviation of the AMT_CREDIT is:  349364.5479506317
# Number of missing values in the AMT_CREDIT is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["AMT_CREDIT"],ax=ax[0])
sns.boxplot(x=df["AMT_CREDIT"],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation: Most likely, credit amt loan of the applicant follows a normal distribution. Most of the credit amt loan of are between 0.2 to 0.8.

# %% [markdown]
# # 11. Analysis of  the AMT_GOODS_PRICE
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_num("AMT_GOODS_PRICE")
# Out:
# The mean of the AMT_GOODS_PRICE is:  538345.14885
# The median of the AMT_GOODS_PRICE is:  450000.0
# The mode of the AMT_GOODS_PRICE is:  450000.0
# The standard deviation of the AMT_GOODS_PRICE is:  369248.0867594922
# Number of missing values in the AMT_GOODS_PRICE is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["AMT_GOODS_PRICE"],ax=ax[0])
sns.boxplot(x=df["AMT_GOODS_PRICE"],ax=ax[1])
plt.show()

# %% [markdown]
# # Outliers Analysis and Treatment:
# Since the data is skwed IQR based filtering can be used.

# %%
df["AMT_GOODS_PRICE"].describe()
# Out:
# count    1.000000e+05
# mean     5.383451e+05
# std      3.692481e+05
# min      4.500000e+04
# 25%      2.385000e+05
# 50%      4.500000e+05
# 75%      6.795000e+05
# max      4.050000e+06
# Name: AMT_GOODS_PRICE, dtype: float64

# %%
percentile_1= 2.385000e+05
percentile_3=6.795000e+05
IQR=percentile_3-percentile_1

# %%
upper_limit=percentile_3+1.5*IQR
lower_limit=percentile_1-1.5*IQR

# %%
#Finding Outliers
df1=df[df["AMT_GOODS_PRICE"]>upper_limit]
df2=df[df["AMT_GOODS_PRICE"]<lower_limit]

# %%
mean=df["AMT_GOODS_PRICE"].mean()
x=df1.index
for index in x:
    df.loc[index,"AMT_GOODS_PRICE"]=mean

# %%
info_of_num("AMT_GOODS_PRICE")
# Out:
# The mean of the AMT_GOODS_PRICE is:  489239.4066583673
# The median of the AMT_GOODS_PRICE is:  450000.0
# The mode of the AMT_GOODS_PRICE is:  450000.0
# The standard deviation of the AMT_GOODS_PRICE is:  283948.34869709075
# Number of missing values in the AMT_GOODS_PRICE is:  0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.histplot(x=df["AMT_GOODS_PRICE"],ax=ax[0])
sns.boxplot(x=df["AMT_GOODS_PRICE"],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation: Most likely, AMT_GOODS_PRICE of the applicant follows a normal distribution. Most of the AMT_GOODS_PRICE of are between 0.2 to 0.8.

# %%
df["GENDER"]
# Out:
# 0        M
# 1        F
# 2        M
# 3        F
# 4        M
#         ..
# 99995    F
# 99996    F
# 99997    F
# 99998    F
# 99999    M
# Name: GENDER, Length: 100000, dtype: object

# %%
df4=df[df["GENDER"]=="F"]
f=df4.groupby(["GENDER"])["NAME_CONTRACT_TYPE"].value_counts()
f
# Out:
# GENDER  NAME_CONTRACT_TYPE
# F       Cash loans            59478
#         Revolving loans        6377
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
df5=df[df["GENDER"]=="M"]
m=df5.groupby(["GENDER"])["NAME_CONTRACT_TYPE"].value_counts()
m
# Out:
# GENDER  NAME_CONTRACT_TYPE
# M       Cash loans            31039
#         Revolving loans        3103
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
m.plot(kind='pie',ax=ax[0],autopct="%0.2f%%")
f.plot(kind='pie',ax=ax[1],autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='NAME_CONTRACT_TYPE'>

# %% [markdown]
# ## From the above analysis it clear thar more males and females have applied for cash loans than revolving loans.One reason may be because it is easy for them to apply.

# %% [markdown]
# ## Analysis of males and females who own a car

# %%
f1=df4.groupby(["GENDER"])["Car"].value_counts()
f1
# Out:
# GENDER  Car
# F       N      51267
#         Y      14588
# Name: Car, dtype: int64

# %%
m1=df5.groupby(["GENDER"])["Car"].value_counts()
m1
# Out:
# GENDER  Car
# M       Y      19393
#         N      14749
# Name: Car, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
m1.plot(kind='pie',ax=ax[0],autopct="%0.2f%%")
f1.plot(kind='pie',ax=ax[1],autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='Car'>

# %% [markdown]
# ## From the analysis 58.06% and 24.87 of males and females own car.

# %% [markdown]
# ## Analysis of males and females who own a house

# %%
f2=df4.groupby(["GENDER"])["House"].value_counts()
f2
# Out:
# GENDER  House
# F       Y        46560
#         N        19295
# Name: House, dtype: int64

# %%
m2=df5.groupby(["GENDER"])["House"].value_counts()
m2
# Out:
# GENDER  House
# M       Y        22765
#         N        11377
# Name: House, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
f2.plot(kind='pie',ax=ax[0],autopct="%0.2f%%")
m2.plot(kind='pie',ax=ax[1],autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='House'>

# %% [markdown]
# ## From the analysis 65.97% and 69.10% of males and females own a house.

# %% [markdown]
# # 1.Analyze the women clients who have applied loan in the form of cash based on their education levels.

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df['NAME_CONTRACT_TYPE']
# Out:
# 0             Cash loans
# 1             Cash loans
# 2        Revolving loans
# 3             Cash loans
# 4             Cash loans
#               ...
# 99995         Cash loans
# 99996         Cash loans
# 99997         Cash loans
# 99998         Cash loans
# 99999    Revolving loans
# Name: NAME_CONTRACT_TYPE, Length: 100000, dtype: object

# %%
data=df[(df["GENDER"]=='F') & (df["NAME_CONTRACT_TYPE"]=='Cash loans')]
data['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary / secondary special    42589
# Higher education                 14431
# Incomplete higher                 1717
# Lower secondary                    710
# Academic degree                     31
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
data=df[(df["GENDER"]=='F') & (df["NAME_CONTRACT_TYPE"]=='Cash loans')]
data=data['NAME_EDUCATION_TYPE'].value_counts()
x = pd.DataFrame({"data" : data.values.tolist(), "index":data.index.tolist()})
pie, ax = plt.subplots(figsize = [10,6])
plt.title("Female Applicants")
plt.barh(y = x["index"], width = x["data"])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Interpretation: Based on the education level, secondary/secondary special females are applying more loans as compared to those who are higher education or academic degree.

# %% [markdown]
# ## Analysis of males and females who have made late payments

# %%
df.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the analysis it is clear that more female and male applicants had late payment more than X days on at least one of the first Y installments of the loan in our sample as compared to the others who have not paide their payments due to other reasons

# %% [markdown]
# ## 3.Females who have applied for cash loans and revolving loans and are on maternity leaves.

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
data=df[(df["GENDER"]=='F') | (df["NAME_INCOME_TYPE"]=='Maternity leave')]
data["NAME_CONTRACT_TYPE"].value_counts().plot(kind='pie',autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='NAME_CONTRACT_TYPE'>

# %% [markdown]
# ## 90.32% of the females who are on the maternity leave and have applied for cash loan.

# %% [markdown]
# Education Loan,personal,vehicle,education loans

# %% [markdown]
# Important Factors Lenders Look at to Approve your Application
# 1.Credit Score
# Credit score plays an important role in deciding whether the lender would like to go ahead with your application or drop it off at the initial stage. This is especially the case when it comes to unsecured loans.
#
# Since a credit score represents the credit history of the borrower, the lender analyses the repayment history of the borrower and concludes whether the borrower can repay on time or will he default on payments. The loan approval is based on the lender’s judgement after the necessary analysis.
#
# Income and Employment History
# Your monthly or annual income and employment history plays a crucial role in loan approval as well. Based on your income and income stability in the form of consistent and stable work history, the lender may or may not get convinced that you will be able to repay the loan.
#
# Even if you are self-employed, the lender assumes that your business is running well for the past few years and your business’s turnover is satisfactory.
#
# Debt-to-Income Ratio
# Not just having a good income, your debt-to-income ratio is also important. In case you have an income of Rs.1 lakh per month and if your debt repayment commitments exceed Rs.75,000 already, a new loan will not be provided to you as you will need the remaining income to take care of your domestic expenses.
#
# Therefore, irrespective of your income, you must have a low debt-to-income ratio so the lenders can think that you have enough cash at hand every month to make the repayments as well as handle the family expenses.
#
# Collateral
# Based on the collateral you provide and its current market value, the lender may decide on the interest rate applicable to your loan. Providing collateral will make the deal more secure from the lender’s perspective, which may result in more trust and less interest rate. An unsecured loan is infamous as it includes a higher interest rate comparatively.
#
# Down Payment
# The money you have saved and the effective execution of your saving plan towards a down payment will increase the lender’s trust in you. The higher the down payment, the lower is the loan amount requirement.

# %% [markdown]
# ## Analysis of Applicants who have applied for education loan

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df['NAME_INCOME_TYPE'].unique()
# Out:
# array(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
data=df[(df["NAME_INCOME_TYPE"]=="Student")]

# %%
data.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the above analysis it is clear that the students(males and females) have a good credit score ie they have never delayed to repay their loan.

# %% [markdown]
# ## Monthly or annual income

# %%
data.groupby(["GENDER"])["AMT_INCOME_TOTAL"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## From the analysis it is clear that  the avg total income of men is greater than that of female which means that there is a slight possibility that application of men would pass through than female.

# %% [markdown]
# ## Genderwise Occupation

# %%
data.groupby(["GENDER"])["OCCUPATION_TYPE"].value_counts()
# Out:
# GENDER  OCCUPATION_TYPE
# F       Core staff              2
#         Laborers                1
#         Waiters/barmen staff    1
# M       Laborers                3
#         Drivers                 1
#         Unemployed              1
# Name: OCCUPATION_TYPE, dtype: int64

# %%
sns.countplot(data = data, x = 'GENDER',hue ='OCCUPATION_TYPE')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that all the students who have applied for student loans one of them is umemployed which show the possibility that the stuent won't be given the loan

# %% [markdown]
# ## Income to debt ratio
#
# #### $$\frac{Total\;Income}{Amount \;Credit}$$
# ## If your debt-income ratio is between 35%-60%, there is a chance that your loan may get approved.

# %%
data.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_7888/3915170728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100

# %%
data.groupby(["GENDER"])["Income_to_debt_ratio"].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## Max value of Income_to_debt_ratio for a male applicant is 200+ which will definitely be rejected since the ratio >60 whereas for the female applicant the rati< 60 which means the application for the loan will be accepted.

# %% [markdown]
# ## Collateral based eligibilty of loan

# %%
sns.countplot(data = data, x = 'GENDER',hue ='Car')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of male students have car as a collateral which can expedite their loan appliation process where female don't have that advantage since they don't own a car as collateral

# %%
sns.countplot(data = data, x = 'GENDER',hue ='House')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of male and female students have house as a collateral which can expedite their loan appliation.

# %% [markdown]
# ## Analysis of Applicants who have applied for house and vehicle loan

# %%
df["NAME_INCOME_TYPE"].unique()
# Out:
# array(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
data=df[df["NAME_INCOME_TYPE"]=='Businessman']

# %%
data.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the above analysis it is clear that the businessmen have a good credit score ie they have never delayed to repay their loan.

# %% [markdown]
# ## Monthly or Annual income

# %%
data.groupby(["GENDER"])["AMT_INCOME_TOTAL"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## From the analysis it is clear that  the avg total income of businessmen is resonabaly good which means that there is a slight possibility that application of men would pass through.

# %% [markdown]
# ## Genderwise Occupation

# %%
sns.countplot(data = data, x = 'GENDER',hue ='OCCUPATION_TYPE')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that all the businessmen who have applied for home loans one of themare managers and core staff which are hifh paying jobs which show the possibility that the home loan  would be given the loan

# %% [markdown]
# ## Income to debt ratio
#
# #### $$\frac{Total\;Income}{Amount \;Credit}$$
# ## If your debt-income ratio is between 35%-60%, there is a chance that your loan may get approved.

# %%
data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_7888/3915170728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100

# %%
data.groupby(["GENDER"])["Income_to_debt_ratio"].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## Max value of Income_to_debt_ratio for a businessmen applicant is under 35% which will definitely be accepted since the ratio<60.

# %% [markdown]
# ## Collateral based eligibilty of loan

# %%
sns.countplot(data = data, x = 'GENDER',hue ='Car')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of businessmen have car as a collateral which can expedite their loan appliation process.

# %%
sns.countplot(data = data, x = 'GENDER',hue ='House')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of businessmen have house as a collateral which can expedite their loan appliation.

# %% [markdown]
# ## Analysis of Applicants who have applied for house and vehicle loan

# %%
df['NAME_INCOME_TYPE'].unique()
# Out:
# array(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
data=df[(df["NAME_INCOME_TYPE"]=="State servant")]

# %%
data.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the above analysis it is clear that the majority of the state servnts(males and females) have a good credit score ie they have never delayed to repay their loan.

# %%
data.groupby(["GENDER"])["AMT_INCOME_TOTAL"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## From the analysis it is clear that  the avg total income of men is greater than that of female which means that there is a slight possibility that application of men would pass through than female.

# %%
# data.groupby(["GENDER"])["OCCUPATION_TYPE"].value_counts()
# sns.barplot(x='GENDER',y='OCCUPATION_TYPE',data=data)
# sns.countplot(x='GENDER',data=data)
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(data = data, x = 'GENDER',hue ='OCCUPATION_TYPE')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that all the state sevants who have applied for home or vehicle loans are all employed.

# %% [markdown]
# ## Income to debt ratio

# %% [markdown]
# #### $$\frac{Total\;Income}{Amount \;Credit}$$
# ## If your debt-income ratio is between 35%-60%, there is a chance that your loan may get approved.

# %%
data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_11448/3915170728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100

# %%
#data.groupby(["GENDER"])["Income_to_debt_ratio"].min().plot(kind='bar')
d1=data[data["Income_to_debt_ratio"]<60]
d1.groupby(["GENDER"])["Income_to_debt_ratio"].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## Max value of Income_to_debt_ratio for a male and female applicant is 200+ which will definitely be rejected since the ratio >60 whereas ,so we have selected only those male ans female applicant whose  Income_to_debt_ratio is less than 60

# %% [markdown]
# ## Collateral based eligibilty of loan

# %%
sns.countplot(data = data, x = 'GENDER',hue ='Car')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of female state servants have car as a collateral which can expedite their loan appliation process whereas male don't have that advantage since theyless percentage own a house as collateral

# %%
sns.countplot(data = data, x = 'GENDER',hue ='House')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of female state servants have house as a collateral which can expedite their loan appliation.

# %% [markdown]
# ## Analysis of Applicants who have applied for house and vehicle loan

# %%
df['NAME_INCOME_TYPE'].unique()
# Out:
# array(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
data=df[(df["NAME_INCOME_TYPE"]=="Commercial associate")]

# %%
data.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the above analysis it is clear that the associates(males and females) have a good credit score ie they have never delayed to repay their loan.

# %%
data.groupby(["GENDER"])["AMT_INCOME_TOTAL"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## From the analysis it is clear that  the avg total income of men is greater than that of female which means that there is a slight possibility that application of men would pass through than female.

# %%
data.groupby(["GENDER"])["OCCUPATION_TYPE"].value_counts()
# Out:
# GENDER  OCCUPATION_TYPE
# F       Sales staff              3053
#         Unemployed               2743
#         Laborers                 1791
#         Core staff               1639
#         Managers                 1441
#         Accountants              1281
#         High skill tech staff     655
#         Cooking staff             361
#         Medicine staff            325
#         Private service staff     302
#         Cleaning staff            246
#         Security staff            108
#         Secretaries               100
#         Realty agents              97
#         Waiters/barmen staff       85
#         Drivers                    71
#         HR staff                   64
#         IT staff                   18
#         Low-skill Laborers         14
# M       Laborers                 2363
#         Drivers                  1565
#         Managers                 1437
#         Unemployed               1231
#         Sales staff               545
# ...

# %% [markdown]
# ## From the analysis it is clear that all the associates who have applied for  loans some of them are umemployed which show the possibility that the they won't be given the loan

# %% [markdown]
# ## Income to debt ratio

# %% [markdown]
# #### $$\frac{Total\;Income}{Amount \;Credit}$$
# ## If your debt-income ratio is between 35%-60%, there is a chance that your loan may get approved.

# %%
data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_11448/3915170728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Income_to_debt_ratio"]=(data["AMT_INCOME_TOTAL"]/data["AMT_CREDIT"]) *100

# %%
d1=data[data["Income_to_debt_ratio"]<60]
d1.groupby(["GENDER"])["Income_to_debt_ratio"].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## Max value of Income_to_debt_ratio for a male and females applicant is 200+ which will definitely be rejected since the ratio >60 so applicats whose Income_to_debt_ratio is less than 60 is selected.

# %% [markdown]
# ## Collateral based eligibilty of loan

# %%
sns.countplot(data = data, x = 'GENDER',hue ='Car')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of male and feamle associates have car as a collateral which can expedite their loan appliation process.

# %%
sns.countplot(data = data, x = 'GENDER',hue ='House')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that a certain percentage of male and female commercial associates have house as a collateral which can expedite their loan appliation.

# %% [markdown]
# ## Analysis of Applicants who have applied for house and vehicle loan

# %%
df['NAME_INCOME_TYPE'].unique()
# Out:
# array(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
data=df[(df["NAME_INCOME_TYPE"]=="Pensioner")]

# %%
data.groupby(["GENDER"])["TARGET"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER,TARGET'>

# %% [markdown]
# ## From the above analysis it is clear that the pensioners(males and females) have a good credit score ie they have never delayed to repay their loan.

# %%
data.groupby(["GENDER"])["AMT_INCOME_TOTAL"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GENDER'>

# %% [markdown]
# ## From the analysis it is clear that  the avg total income of men is greater than that of female which means that there is a slight possibility that application of men would pass through than female.

# %%
sns.countplot(data = data, x = 'GENDER',hue ='OCCUPATION_TYPE')
# Out:
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %% [markdown]
# ## From the analysis it is clear that all the pensioners won't be given any loan since they have no staedy jobs.

# %% [markdown]
# ## Conclusion
#
# From the above analysis done by the data analyst who works for The Gold Atlantis. it is clear that the person who has an occupation of a State Servant has applied for a home/car loan will be able to get his application easily passed since he/she has a steady job and a good pay and fulfills all other eligibility criteria.
